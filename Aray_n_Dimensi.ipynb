# %% [markdown]
# <a href="https://colab.research.google.com/github/dwimaniks/dwimanik/blob/main/Aray_n_Dimensi.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

arr3d = np.array([
    [[1,2],[3,4]],
    [[5,6],[7,8]]
])
print(arr3d)
# Out:
# [[[1 2]
#   [3 4]]
#
#  [[5 6]
#   [7 8]]]

# %%
# import library numpy
import numpy as np

# %%
# 1. Array 3D berukuran 2x2x2.
array_3d = np.array([[[1, 2], [3, 4]], [[5, 6], [7, 8]]])
print("Array 3D berukuran 2x2x2:")
print(array_3d)
# Out:
# Array 3D berukuran 2x2x2:
# [[[1 2]
#   [3 4]]
#
#  [[5 6]
#   [7 8]]]

# %%
# 2. Tampilkan elemen pada indeks [1][0][1].
print("Elemen pada indeks [1][0][1]:", array_3d[1, 0, 1])
# Out:
# Elemen pada indeks [1][0][1]: 6

# %%
# 3. Hitung total seluruh elemen array 3D.
total = np.sum(array_3d)
print("Total seluruh elemen array 3D:", total)
# Out:
# Total seluruh elemen array 3D: 36
